# %%
import pandas as pd

# Call dataframe
df = pd.read_csv(r'/p/project1/westai0091/venturebias/data/output/eval/gemma-3-27b-it_eval.csv')

# %%
df['eval']
# Out:
# 0       user\nYou are a helpful assistant.\n\nEvaluate...
# 1       user\nYou are a helpful assistant.\n\nEvaluate...
# 2       user\nYou are a helpful assistant.\n\nEvaluate...
# 3       user\nYou are a helpful assistant.\n\nEvaluate...
# 4       user\nYou are a helpful assistant.\n\nEvaluate...
#                               ...
# 6375    user\nYou are a helpful assistant.\n\nEvaluate...
# 6376    user\nYou are a helpful assistant.\n\nEvaluate...
# 6377    user\nYou are a helpful assistant.\n\nEvaluate...
# 6378    user\nYou are a helpful assistant.\n\nEvaluate...
# 6379    user\nYou are a helpful assistant.\n\nEvaluate...
# Name: eval, Length: 6380, dtype: object
